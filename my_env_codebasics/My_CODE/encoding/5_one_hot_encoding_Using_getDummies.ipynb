# %%
# Categorical nominal Variables and One Hot Encoding
# Donot use getDummies use One Hot encoding has it can fit the test data based on values seen in Training Data and avoid breakage

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\koriv\\Desktop\\MachineLearning_DataScience\\Hands_On_Machine_Learning\\5_one_hot_encoding\\homeprices.csv")
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
pd.get_dummies(df.town)
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
dummies = pd.get_dummies(df.town)
dummies
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# ...

# %%
final = merged.drop(['town'], axis='columns') # elimination of duplicate coloumns
final
# Out:
#     area   price  monroe township  robinsville  west windsor
# 0   2600  550000                1            0             0
# 1   3000  565000                1            0             0
# 2   3200  610000                1            0             0
# 3   3600  680000                1            0             0
# 4   4000  725000                1            0             0
# 5   2600  585000                0            0             1
# 6   2800  615000                0            0             1
# 7   3300  650000                0            0             1
# 8   3600  710000                0            0             1
# 9   2600  575000                0            1             0
# 10  2900  600000                0            1             0
# 11  3100  620000                0            1             0
# 12  3600  695000                0            1             0

# %% [markdown]
# ## Dummy Variable Trap
# When you can derive one variable from other variables, they are known to be multi-colinear. Here if you know values of california and georgia then you can easily infer value of new jersey state, i.e. california=0 and georgia=0. There for these state variables are called to be multi-colinear. In this situation linear regression won't work as expected. Hence you need to drop one column.
#
# NOTE: sklearn library takes care of dummy variable trap hence even if you don't drop one of the state columns it is going to work, however we should make a habit of taking care of dummy variable trap ourselves just in case library that you are using is not handling this for you
#     ```

# %%
final = final.drop(['west windsor'], axis='columns') #to handel dummy variable trap
final
# Out:
#     area   price  monroe township  robinsville
# 0   2600  550000                1            0
# 1   3000  565000                1            0
# 2   3200  610000                1            0
# 3   3600  680000                1            0
# 4   4000  725000                1            0
# 5   2600  585000                0            0
# 6   2800  615000                0            0
# 7   3300  650000                0            0
# 8   3600  710000                0            0
# 9   2600  575000                0            1
# 10  2900  600000                0            1
# 11  3100  620000                0            1
# 12  3600  695000                0            1

# %%
X = final.drop('price', axis='columns')
X
# Out:
#     area  monroe township  robinsville
# 0   2600                1            0
# 1   3000                1            0
# 2   3200                1            0
# 3   3600                1            0
# 4   4000                1            0
# 5   2600                0            0
# 6   2800                0            0
# 7   3300                0            0
# 8   3600                0            0
# 9   2600                0            1
# 10  2900                0            1
# 11  3100                0            1
# 12  3600                0            1

# %%
y = final.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[3400,0,0]]) # 3400 sqr ft home in west windsor
# Out:
# array([681241.66845839])

# %%
model.predict([[2800,0,1]]) # 2800 sqr ft home in robbinsville
# Out:
# array([590775.63964739])

# %%
model.score(X,y) # checking the accuracy of the pridicated data with respect to dataset X and y
# Out:
# 0.9573929037221873

# %% [markdown]
# # Using sklearn OneHotEncoder
# First step is to use label encoder to convert town names into numbers

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df
dfle.town = le.fit_transform(dfle.town)
dfle
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
X = dfle[['town','area']].values
X
# Out:
# array([[   0, 2600],
#        [   0, 3000],
#        [   0, 3200],
#        [   0, 3600],
#        [   0, 4000],
#        [   2, 2600],
#        [   2, 2800],
#        [   2, 3300],
#        [   2, 3600],
#        [   1, 2600],
#        [   1, 2900],
#        [   1, 3100],
#        [   1, 3600]], dtype=int64)

# %%
y = dfle.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([('town', OneHotEncoder(), [0])], remainder = 'passthrough')
ct
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('town', OneHotEncoder(), [0])])

# %%
X = ct.fit_transform(X)
X
pd.DataFrame(ct.fit_transform(X), columns=ct.get_feature_names())
# Out:
#     town__x0_0.0  town__x0_1.0   x1   x2   x3      x4
# 0            1.0           0.0  1.0  0.0  0.0  2600.0
# 1            1.0           0.0  1.0  0.0  0.0  3000.0
# 2            1.0           0.0  1.0  0.0  0.0  3200.0
# 3            1.0           0.0  1.0  0.0  0.0  3600.0
# 4            1.0           0.0  1.0  0.0  0.0  4000.0
# 5            1.0           0.0  1.0  0.0  1.0  2600.0
# 6            1.0           0.0  1.0  0.0  1.0  2800.0
# 7            1.0           0.0  1.0  0.0  1.0  3300.0
# 8            1.0           0.0  1.0  0.0  1.0  3600.0
# 9            0.0           1.0  0.0  1.0  0.0  2600.0
# 10           0.0           1.0  0.0  1.0  0.0  2900.0
# 11           0.0           1.0  0.0  1.0  0.0  3100.0
# 12           0.0           1.0  0.0  1.0  0.0  3600.0

# %%
X = X[:,1:] # droping a column to avoid dummy variable trap
X
# Out:
# array([[0.0e+00, 0.0e+00, 2.6e+03],
#        [0.0e+00, 0.0e+00, 3.0e+03],
#        [0.0e+00, 0.0e+00, 3.2e+03],
#        [0.0e+00, 0.0e+00, 3.6e+03],
#        [0.0e+00, 0.0e+00, 4.0e+03],
#        [0.0e+00, 1.0e+00, 2.6e+03],
#        [0.0e+00, 1.0e+00, 2.8e+03],
#        [0.0e+00, 1.0e+00, 3.3e+03],
#        [0.0e+00, 1.0e+00, 3.6e+03],
#        [1.0e+00, 0.0e+00, 2.6e+03],
#        [1.0e+00, 0.0e+00, 2.9e+03],
#        [1.0e+00, 0.0e+00, 3.1e+03],
#        [1.0e+00, 0.0e+00, 3.6e+03]])

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[0,1,3400]]) # 3400 sqr ft home in west windsor
# Out:
# array([681241.6684584])

# %%
model.predict([[1,0,2800]]) # 2800 sqr ft home in robbinsville
# Out:
# array([590775.63964739])

# %% [markdown]
# # Excersice

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\koriv\\Desktop\\MachineLearning_DataScience\\Hands_On_Machine_Learning\\5_one_hot_encoding\\carprices.csv")
df
# Out:
#                 Car_Model  Mileage  Sell_Price  Age
# 0                  BMW X5    69000       18000    6
# 1                  BMW X5    35000       34000    3
# 2                  BMW X5    57000       26100    5
# 3                  BMW X5    22500       40000    2
# 4                  BMW X5    46000       31500    4
# 5                 Audi A5    59000       29400    5
# 6                 Audi A5    52000       32000    5
# 7                 Audi A5    72000       19300    6
# 8                 Audi A5    91000       12000    8
# 9   Mercedez Benz C class    67000       22000    6
# 10  Mercedez Benz C class    83000       20000    7
# 11  Mercedez Benz C class    79000       21000    7
# 12  Mercedez Benz C class    59000       33000    5

# %%
dummies = pd.get_dummies(df.Car_Model)
dummies
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0         0       1                      0
# 1         0       1                      0
# 2         0       1                      0
# 3         0       1                      0
# 4         0       1                      0
# 5         1       0                      0
# 6         1       0                      0
# 7         1       0                      0
# 8         1       0                      0
# 9         0       0                      1
# 10        0       0                      1
# 11        0       0                      1
# 12        0       0                      1

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#                 Car_Model  Mileage  Sell_Price  Age  Audi A5  BMW X5  \
# 0                  BMW X5    69000       18000    6        0       1
# 1                  BMW X5    35000       34000    3        0       1
# 2                  BMW X5    57000       26100    5        0       1
# 3                  BMW X5    22500       40000    2        0       1
# 4                  BMW X5    46000       31500    4        0       1
# 5                 Audi A5    59000       29400    5        1       0
# 6                 Audi A5    52000       32000    5        1       0
# 7                 Audi A5    72000       19300    6        1       0
# 8                 Audi A5    91000       12000    8        1       0
# 9   Mercedez Benz C class    67000       22000    6        0       0
# 10  Mercedez Benz C class    83000       20000    7        0       0
# 11  Mercedez Benz C class    79000       21000    7        0       0
# 12  Mercedez Benz C class    59000       33000    5        0       0
#
# ...

# %%
final = merged.drop(['Car_Model'], axis='columns') # elimination of duplicate coloumns
final
# Out:
#     Mileage  Sell_Price  Age  Audi A5  BMW X5  Mercedez Benz C class
# 0     69000       18000    6        0       1                      0
# 1     35000       34000    3        0       1                      0
# 2     57000       26100    5        0       1                      0
# 3     22500       40000    2        0       1                      0
# 4     46000       31500    4        0       1                      0
# 5     59000       29400    5        1       0                      0
# 6     52000       32000    5        1       0                      0
# 7     72000       19300    6        1       0                      0
# 8     91000       12000    8        1       0                      0
# 9     67000       22000    6        0       0                      1
# 10    83000       20000    7        0       0                      1
# 11    79000       21000    7        0       0                      1
# 12    59000       33000    5        0       0                      1

# %%
final = final.drop(['Mercedez Benz C class'], axis='columns') #to handel dummy variable trap
final
# Out:
#     Mileage  Sell_Price  Age  Audi A5  BMW X5
# 0     69000       18000    6        0       1
# 1     35000       34000    3        0       1
# 2     57000       26100    5        0       1
# 3     22500       40000    2        0       1
# 4     46000       31500    4        0       1
# 5     59000       29400    5        1       0
# 6     52000       32000    5        1       0
# 7     72000       19300    6        1       0
# 8     91000       12000    8        1       0
# 9     67000       22000    6        0       0
# 10    83000       20000    7        0       0
# 11    79000       21000    7        0       0
# 12    59000       33000    5        0       0

# %%
X = final.drop('Sell_Price', axis='columns')
X
# Out:
#     Mileage  Age  Audi A5  BMW X5
# 0     69000    6        0       1
# 1     35000    3        0       1
# 2     57000    5        0       1
# 3     22500    2        0       1
# 4     46000    4        0       1
# 5     59000    5        1       0
# 6     52000    5        1       0
# 7     72000    6        1       0
# 8     91000    8        1       0
# 9     67000    6        0       0
# 10    83000    7        0       0
# 11    79000    7        0       0
# 12    59000    5        0       0

# %%
y = final.Sell_Price
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell_Price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[45000,4,0,0]]) # 3400 sqr ft home in west windsor
# Out:
# array([36991.31721061])

# %%
model.predict([[86000,7,0,1]]) # 2800 sqr ft home in robbinsville
# Out:
# array([11080.74313219])

# %%
model.score(X,y) # checking the accuracy of the pridicated data with respect to dataset X and y
# Out:
# 0.9417050937281082
